# %%
import csv

# Define the filename of the CSV file
filename = "Template_for_upload.csv"

# Initialize a set to store unique pairs of values
unique_values = set()

# Open the CSV file
with open(filename, newline='') as csvfile:
    # Create a CSV reader object
    reader = csv.reader(csvfile)
    
    # Iterate over each row in the CSV file
    for row in reader:
        # Get the values from column 0 and column 63
        value1 = row[2]  # Assuming column 0 is the first column
        value2 = row[3]  # Assuming column 63 is the 64th column (0-indexed)
        
        # Check if the pair of values is not in the set of unique values
        if (value1, value2) not in unique_values:
            # Print the pair of values
            print(f"{value1} | {value2}")
            # Add the pair of values to the set of unique values
            unique_values.add((value1, value2))
# Out:
#  |
# Credit Officer | Group Name
# 1050 - Doreen Namubiru |
# 1051 - Timothy Lasuba |
# 1106 - Edmond Angwala |
# 1106 - Edmond Angwala | PURIDIROFARMERSGROUPANYAMBAZI
# 1111 - Opoka Kalema George |
# 1111 - Opoka Kalema George | APITPENINOFARMERSGROUP
# 1111 - Opoka Kalema George | OGENRWOT ATAPARA
# 1115 - FO-Ambrose Ongom |
# 1117 - FO-Moses Omodo |
# 1118 - FO-Patrick Okot |
# 1119 - Ivan Okua |
# 1121 - FO-Sakina Akello |
# 1122 - FO-Nancy Alum Alinga |
# 1123 - Sande Welikhe |
# 1124 - Fiona Akio |
# 1125 - Flavia Apiyo | OBANGA BER GROUP OYAM
# 1125 - Flavia Apiyo | Oryem Can Farmers
# 1125 - Flavia Apiyo | TIC TEK FARMERS GROUP ACABA
# 1125 - Flavia Apiyo | CWINY MITO KOM WAC
# 1125 - Flavia Apiyo | OBANGA AMIO VSLA AND FARMERS GROUP
# 1125 - Flavia Apiyo |
# 1125 - Flavia Apiyo | ACAN KWO IIWETE GROUP
# 1125 - Flavia Apiyo | KIDILANI FARMERS GROUP
# 1125 - Flavia Apiyo | PUR BER FARMERS GROUP
# 1125 - Flavia Apiyo | WIRAO FARMERS GROUP
# ...
